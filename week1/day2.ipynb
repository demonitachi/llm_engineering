# %%
openai = OpenAI(base_url='http://localhost:11434/v1', api_key='ollama')
message = "Hello, Llama! This is my first ever message to you! Hi!"
response = openai.chat.completions.create(model="llama3.2", messages=[{"role":"user", "content":message}])
print(response.choices[0].message.content)

# %%
api_key = "ollama"
model = "llama3.2"
url = "http://localhost:11434/v1/chat/completions"

# %%
import requests

headers = {"Authorization": f"Bearer {api_key}", "Content-Type": "application/json"}

payload = {
    "model": model,
    "messages": [
        {"role": "user", "content": "Tell me a fun fact"}]
}

payload
# Out:
# {'model': 'llama3.2',
#  'messages': [{'role': 'user', 'content': 'Tell me a fun fact'}]}

# %%
response = requests.post(
    url,
    headers=headers,
    json=payload
)

response.json()
# Out:
# {'id': 'chatcmpl-810',
#  'object': 'chat.completion',
#  'created': 1778184335,
#  'model': 'llama3.2',
#  'system_fingerprint': 'fp_ollama',
#  'choices': [{'index': 0,
#    'message': {'role': 'assistant',
#     'content': "Here's a fun fact:\n\nDid you know that honey never spoils? Archaeologists have found pots of honey in ancient Egyptian tombs that are over 3,000 years old and still perfectly edible! Honey's durability is due to its unique composition, which makes it acidic and resistant to bacteria and other microorganisms. This means that honey can withstand extreme temperatures, humidity, and even decay, making it one of the longest-lasting foods in history!\n\nWould you like to hear another fun fact?"},
#    'finish_reason': 'stop'}],
#  'usage': {'prompt_tokens': 30, 'completion_tokens': 100, 'total_tokens': 130}}

# %%
response
# Out:
# <Response [200]>

# %%
print(response.json()["choices"][0]["message"]["content"])
# Out:
# Here's a fun fact:
#
# Did you know that honey never spoils? Archaeologists have found pots of honey in ancient Egyptian tombs that are over 3,000 years old and still perfectly edible! Honey's durability is due to its unique composition, which makes it acidic and resistant to bacteria and other microorganisms. This means that honey can withstand extreme temperatures, humidity, and even decay, making it one of the longest-lasting foods in history!
#
# Would you like to hear another fun fact?

# %%
from openai import OpenAI

# %%
url = "http://localhost:11434/v1"
model_name = "gemma3:4b"
message = "Hello, Llama! This is my first ever message to you! Hi!"

# %%
openai = OpenAI(base_url=url, api_key='ollama')

# %%
response = openai.chat.completions.create(model=model_name, messages=[{"role":"user", "content":message}])
print(response.choices[0].message.content)
# Out:
# Hello there! It's absolutely fantastic to hear from you! Hi back to you! 😊
#
# It’s wonderful to be your first interaction with me. Don't hesitate to ask me anything – I'm here to chat, answer questions, and just have a conversation.
#
# What's on your mind today? 😄

# %%
# Out:
# NAME               ID              SIZE      MODIFIED
# gemma3:4b          a2af6cc3eb7f    3.3 GB    5 minutes ago
# llama3.2:latest    a80c4f17acd5    2.0 GB    11 months ago
