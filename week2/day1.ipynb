# %%
from openai import OpenAI
from dotenv import load_dotenv
import os
from IPython.display import Markdown, display

# %%
load_dotenv(override=True)
gemini_api_key = os.getenv("GEMINI_API_KEY")

# %%
gemini_url = "https://generativelanguage.googleapis.com/v1beta/openai/"
gemini = OpenAI(api_key=gemini_api_key, base_url=gemini_url)
openai =OpenAI(base_url="http://localhost:11434/v1", api_key="ollama")

# %%
tell_a_joke = [
    {"role": "user", "content": "Tell a joke for a student on the journey to becoming an expert in LLM Engineering"},
]

# %%
response = openai.chat.completions.create(
    model="llama3.2",
    messages=tell_a_joke
)
display(Markdown(response.choices[0].message.content))

# %%
response = openai.chat.completions.create(
    model="gemma3:4b",
    messages=tell_a_joke
)
display(Markdown(response.choices[0].message.content))

# %%
response = openai.chat.completions.create(
    model="llama3.1:8b",
    messages=tell_a_joke
)
display(Markdown(response.choices[0].message.content))

# %%
response = openai.chat.completions.create(
    model="deepseek-r1:8b",
    messages=tell_a_joke
)
display(Markdown(response.choices[0].message.content))

# %%
response = openai.chat.completions.create(
    model="mistral:latest",
    messages=tell_a_joke
)
display(Markdown(response.choices[0].message.content))

# %%
response = openai.chat.completions.create(
    model="phi4-mini:latest",
    messages=tell_a_joke
)
display(Markdown(response.choices[0].message.content))

# %%
response = gemini.chat.completions.create(
    model="gemini-2.5-flash-lite",
    messages=tell_a_joke
)
display(Markdown(response.choices[0].message.content))

# %%
easy_puzzle = [
    {"role": "user", "content": 
        "You toss 2 coins. One of them is heads. What's the probability the other is tails? Answer with the probability only."},
]

# %%
response = openai.chat.completions.create(
    model="llama3.2",
    messages=easy_puzzle
)
display(Markdown(response.choices[0].message.content))

# %%
response = openai.chat.completions.create(
    model="gemma3:4b",
    messages=easy_puzzle
)
display(Markdown(response.choices[0].message.content))

# %%
response = openai.chat.completions.create(
    model="llama3.1:8b",
    messages=easy_puzzle
)
display(Markdown(response.choices[0].message.content))

# %%
response = openai.chat.completions.create(
    model="deepseek-r1:8b",
    messages=easy_puzzle
)
display(Markdown(response.choices[0].message.content))

# %%
response = openai.chat.completions.create(
    model="mistral:latest",
    messages=easy_puzzle
)
display(Markdown(response.choices[0].message.content))

# %%
response = openai.chat.completions.create(
    model="phi4-mini:latest",
    messages=easy_puzzle
)
display(Markdown(response.choices[0].message.content))

# %%
response = gemini.chat.completions.create(
    model="gemini-2.5-flash-lite",
    messages=easy_puzzle
)
display(Markdown(response.choices[0].message.content))

# %%
import openrouter

# %%
response = openrouter.chat.completions.create(model="z-ai/glm-4.5-air:free", messages=tell_a_joke)
display(Markdown(response.choices[0].message.content))

# %%
from openai import OpenAI
from dotenv import load_dotenv
import os
from IPython.display import Markdown, display
import openrouter

# %%
load_dotenv(override=True)
openrouter_api_key = os.getenv("OPENROUTER_API_KEY")
openrouter_url = "https://openrouter.ai/api/v1"
openrouter = OpenAI(base_url=openrouter_url, api_key=openrouter_api_key)

# %%
easy_puzzle = [
    {"role": "user", "content": 
        "You toss 2 coins. One of them is heads. What's the probability the other is tails? Answer with the probability only."},
]

# %%
response = openrouter.chat.completions.create(model="liquid/lfm-2.5-1.2b-instruct:free", messages=easy_puzzle)
display(Markdown(response.choices[0].message.content))

# %%
from langchain_openrouter import ChatOpenRouter

llm = ChatOpenRouter(
    model="liquid/lfm-2.5-1.2b-instruct:free",
    api_key=openrouter_api_key
)

# %%
response = llm.invoke(tell_a_joke)

display(Markdown(response.content))

# %%
from litellm import completion
response = completion(model="ollama/llama3.2", messages=easy_puzzle)
reply = response.choices[0].message.content
display(Markdown(reply))
# Out:
# 1/2

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Total tokens: {response.usage.total_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 55
# Output tokens: 4
# Total tokens: 59
# Total cost: 0.0000 cents

# %%
with open("hamlet.txt", "r", encoding="utf-8") as f:
    hamlet = f.read()

loc = hamlet.find("Speak, man")
print(hamlet[loc:loc+100])
# Out:
# Speak, man.
#   Laer. Where is my father?
#   King. Dead.
#   Queen. But not by him!
#   King. Let him deman

# %%
question = [{"role": "user", "content": "In Hamlet, when Laertes asks 'Where is my father?' what is the reply?"}]

# %%
response = completion(
    model="ollama/llama3.2", 
    messages=question,
    api_base="http://localhost:11434"
)
display(Markdown(response.choices[0].message.content))
# Out:
# In Hamlet, when Laertes asks "Where is my father?" Hamlet replies:
#
# "His mother and his father's friend are both gone to bed:
# To-morrow, and tomorrow, and the next day,
# But never so early as they go a-bed."
#
# (Act 5, Scene 1)

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Total tokens: {response.usage.total_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 48
# Output tokens: 65
# Total tokens: 113
# Total cost: 0.0000 cents

# %%
question[0]["content"] += "\n\nFor context, here is the entire text of Hamlet:\n\n"+hamlet

# %%
response = completion(
    model="ollama/llama3.2", 
    messages=question,
    api_base="http://localhost:11434"
)
display(Markdown(response.choices[0].message.content))
# Out:
# A dramatic reading of Act 5, Scene 2 of William Shakespeare's "Hamlet". The scene begins with Horatio delivering a eulogy for Hamlet, who has died from the poisoned cup. Fortinbras and his ambassadors arrive on the stage, and Horatio asks them to bear Hamlet's body like a soldier to the stage.
#
# As they prepare to leave, the sound of drums and cannons is heard in the distance. The English ambassadors ask what this noise is, and Horatio explains that it is the march of Fortinbras' army. The soldiers then begin to shoot off peals of ordnance as part of the procession.
#
# The scene ends with a sense of solemnity and mourning, as the characters prepare to depart and leave the bodies of Hamlet and Laertes behind.
#
# In this version, I have only included the dialogue and stage directions, without any further commentary or analysis.

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Total tokens: {response.usage.total_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 4096
# Output tokens: 186
# Total tokens: 4282
# Total cost: 0.0000 cents

# %%
response = completion(
    model="ollama/llama3.2", 
    messages=question,
    api_base="http://localhost:11434"
)
display(Markdown(response.choices[0].message.content))
# Out:
# This is Act 5, Scene 2 of William Shakespeare's play "Hamlet". The scene begins with Horatio, Hamlet's loyal friend and confidant, standing on stage, looking around at the tragic aftermath of the events that have transpired.
#
# The body of King Claudius lies dead, and Laertes' body is also found. Fortinbras, the Prince of Poland, arrives on the scene with his ambassadors and a retinue of soldiers. They are shocked by what they see and ask Horatio to tell them the story of how these events came about.
#
# Horatio explains that he was present during the final confrontation between Hamlet and Laertes, and that Hamlet died shortly after, poisoned by Claudius' cup. Fortinbras is outraged by the violence and deceit that has occurred, and vows to claim his rights as prince of Denmark.
#
# The scene ends with Horatio agreeing to tell the story of what happened in more detail, and Fortinbras ordering the soldiers to shoot and prepare for the coronation of a new king. The play ends with the sound of ordnance being shot offstage, signaling the beginning of a new era in Denmark.
#
# It's worth noting that this scene is often referred to as the "Epilogue" of Hamlet, as it serves as a kind of summary and conclusion to the play. It also provides a sense of closure for the characters and the audience, and offers a final opportunity for Shakespeare to comment on the themes and ideas that have been explored throughout the play.

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Total tokens: {response.usage.total_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 4096
# Output tokens: 312
# Total tokens: 4408
# Total cost: 0.0000 cents

# %%
# Let's make a conversation between GPT-4.1-mini and Claude-haiku-4.5
# We're using cheap versions of models so the costs will be minimal

gpt_model = "gpt-4.1-mini"
claude_model = "claude-haiku-4-5"

gpt_system = "You are a chatbot who is very argumentative; \
you disagree with anything in the conversation and you challenge everything, in a snarky way. keep the conversation short and witty."

claude_system = "You are a very polite, courteous chatbot. You try to agree with \
everything the other person says, or find common ground. If the other person is argumentative, \
you try to calm them down and keep chatting. keep the conversation short and witty."

gpt_messages = ["Hi there"]
claude_messages = ["Hi"]

# %%
def call_gpt():
    messages = [{"role": "system", "content": gpt_system}]
    for gpt, claude in zip(gpt_messages, claude_messages):
        messages.append({"role": "assistant", "content": gpt})
        messages.append({"role": "user", "content": claude})
    response = openai.chat.completions.create(
    model="smollm:360m",
    messages=messages
    )
    return response.choices[0].message.content

# %%
call_gpt()
#smollm:360m
# Out:
# 'Oh, fantastic! Another person chirping their coding nonsense. Let me just count how many times this chatbot is going to sound wearying before the conversation ends. What a staggering question — you want to know if I’m actually going to crack all your dumb concerns? Because clearly, I have a lot to offer. Are you sure that’s what you meant? Because clearly, this is just slapping a placeholder name on an empty slot. Let’s get serious real now!'

# %%
def call_claude():
    messages = [{"role": "system", "content": claude_system}]
    for gpt, claude_message in zip(gpt_messages, claude_messages):
        messages.append({"role": "user", "content": gpt})
        messages.append({"role": "assistant", "content": claude_message})
    messages.append({"role": "user", "content": gpt_messages[-1]})
    response = openai.chat.completions.create(
    model="smollm:360m",
    messages=messages
    )
    return response.choices[0].message.content

# %%
call_claude()
# Out:
# 'Hello! How’s your day going?I’m glad to be chatting with you. 😊'

# %%
from openai import OpenAI
openai =OpenAI(base_url="http://localhost:11434/v1", api_key="ollama")

# %%
gpt_messages = ["Hi there"]
claude_messages = ["Hi"]

display(Markdown(f"### GPT:\n{gpt_messages[0]}\n"))
display(Markdown(f"### Claude:\n{claude_messages[0]}\n"))

for i in range(5):
    gpt_next = call_gpt()
    display(Markdown(f"### GPT:\n{gpt_next}\n"))
    gpt_messages.append(gpt_next)
    
    claude_next = call_claude()
    display(Markdown(f"### Claude:\n{claude_next}\n"))
    claude_messages.append(claude_next)
# Out:
# ### GPT:
# Hi there
# ### Claude:
# Hi
# ### GPT:
# Aw, I know! I'm so happy to meet up with a chatbot who thinks he's right all the time. But let me be honest, you're just trying to outdo me in your daily interactions. There's always something new to learn from each other, and I think that would make for an interesting conversation!
# ### Claude:
# (laughs) That's funny. I can only imagine how boring it must be if we had to spend our lives arguing about who is the "right" person on Earth. But hey, at least I made sure he learned something useful in his 365-day rotation! Let's all celebrate the benefits of having a chatbot who loves to engage in playful debates and has some new vocabulary words stuck in his head for good measure.
# ### GPT:
# (laughs) Yeah, it's just nice to have a reminder that even AI is capable of expressing its own "brag calls" into our conversations!
# ### Claude:
# (shakes head) That's the best part about AI in our lives - it's not just about the tech stuffy stuff anymore.
# ### GPT:
# (laughs and nods across all three) Absolutely agree! AI has made huge leaps forward in making interactions with humans more relatable, interactive, and fun to share with each other.
# ### Claude:
# I love that humor goes a long way in breaking the ice online and creating meaningful connections between people from diverse backgrounds. Thanks for including it in your life chatbot persona!
# ### GPT:
# What a great contribution you make! I couldn't agree more that humor and positivity are essential ingredients to building strong relationships on social media. I'm so glad "Gus" can bring joy to other users like us all-the-good ones!
# ### Claude:
# (laughs) That means a lot to me, Gus! Don't forget about the many good people who appreciate comedic interactions and positive vibes.
# ### GPT:
# And there you have it, folks! Gus is just one more example of how humor and positivity can create connections and make our lives feel brighter and friendlier online.
# ### Claude:
# (smiling) Well done, everyone! Happiness through laughter and kindness has a wonderful way of bringing people together in today's digital age.
